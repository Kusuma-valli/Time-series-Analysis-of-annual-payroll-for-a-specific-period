# %%
from ast import increment_lineno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
mv=pd.read_csv("/content/Month_Value_1.csv")

# %%
mv.head()
# Out:
#        Period      Revenue  Sales_quantity  Average_cost  \
# 0  01.01.2015  16010072.12           12729   1257.763541
# 1  01.02.2015  15807587.45           11636   1358.507000
# 2  01.03.2015  22047146.02           15922   1384.697024
# 3  01.04.2015  18814583.29           15227   1235.606705
# 4  01.05.2015  14021479.61            8620   1626.621765
#
#    The_average_annual_payroll_of_the_region
# 0                                  30024676
# 1                                  30024676
# 2                                  30024676
# 3                                  30024676
# 4                                  30024676

# %%
mv.tail()
# Out:
#         Period      Revenue  Sales_quantity  Average_cost  \
# 59  01.12.2019  58756473.66           38069   1543.420464
# 60  01.01.2020  56288300.87           27184   2070.640850
# 61  01.02.2020  40225243.26           23509   1711.057181
# 62  01.03.2020  50022165.23           32569   1535.882748
# 63  01.04.2020  52320692.94           26615   1965.834790
#
#     The_average_annual_payroll_of_the_region
# 59                                  29878525
# 60                                  29044998
# 61                                  29044998
# 62                                  29044998
# 63                                  29044998

# %%
mv.shape
# Out:
# (64, 5)

# %%
mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Period                                    64 non-null     object
#  1   Revenue                                   64 non-null     float64
#  2   Sales_quantity                            64 non-null     int64
#  3   Average_cost                              64 non-null     float64
#  4   The_average_annual_payroll_of_the_region  64 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.6+ KB

# %%
mv.describe()
# Out:
#             Revenue  Sales_quantity  Average_cost  \
# count  6.400000e+01       64.000000     64.000000
# mean   3.236045e+07    19197.375000   1695.061159
# std    1.164150e+07     6591.287257    296.844793
# min    1.402148e+07     8314.000000   1110.576805
# 25%    2.242655e+07    15065.500000   1499.142841
# 50%    3.209088e+07    18368.000000   1654.399797
# 75%    3.992999e+07    22856.250000   1916.401095
# max    5.875647e+07    38069.000000   2559.328184
#
#        The_average_annual_payroll_of_the_region
# count                              6.400000e+01
# mean                               2.869083e+07
# std                                1.057191e+06
# min                                2.740647e+07
# 25%                                2.782857e+07
# 50%                                2.819785e+07
# 75%                                2.987852e+07
# max                                3.002468e+07

# %%
mv.describe(include=object)
# Out:
#             Period
# count           64
# unique          64
# top     01.01.2015
# freq             1

# %%
mv.isnull().sum()
# Out:
# Period                                      0
# Revenue                                     0
# Sales_quantity                              0
# Average_cost                                0
# The_average_annual_payroll_of_the_region    0
# dtype: int64

# %%
mv.dtypes
# Out:
# Period                                       object
# Revenue                                     float64
# Sales_quantity                                int64
# Average_cost                                float64
# The_average_annual_payroll_of_the_region      int64
# dtype: object

# %%
mv.columns
# Out:
# Index(['Period', 'Revenue', 'Sales_quantity', 'Average_cost',
#        'The_average_annual_payroll_of_the_region'],
#       dtype='object')

# %%
mv.duplicated().sum()
# Out:
# 0

# %%
mv.sample()
# Out:
#        Period      Revenue  Sales_quantity  Average_cost  \
# 4  01.05.2015  14021479.61            8620   1626.621765
#
#    The_average_annual_payroll_of_the_region
# 4                                  30024676

# %%
new_df = pd.DataFrame({
    "period": mv["Period"],
    "The_average_annual_payroll_of_the_region": mv["The_average_annual_payroll_of_the_region"]
})

# %%
new_df.head()
# Out:
#        period  The_average_annual_payroll_of_the_region
# 0  01.01.2015                                  30024676
# 1  01.02.2015                                  30024676
# 2  01.03.2015                                  30024676
# 3  01.04.2015                                  30024676
# 4  01.05.2015                                  30024676

# %%
new_df['Period']=pd.to_datetime(mv['Period'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 3 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   period                                    64 non-null     object
#  1   The_average_annual_payroll_of_the_region  64 non-null     int64
#  2   Period                                    64 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
new_df.head()
# Out:
#        period  The_average_annual_payroll_of_the_region     Period
# 0  01.01.2015                                  30024676 2015-01-01
# 1  01.02.2015                                  30024676 2015-01-02
# 2  01.03.2015                                  30024676 2015-01-03
# 3  01.04.2015                                  30024676 2015-01-04
# 4  01.05.2015                                  30024676 2015-01-05

# %%
new_df.describe()
# Out:
#        The_average_annual_payroll_of_the_region
# count                              6.400000e+01
# mean                               2.869083e+07
# std                                1.057191e+06
# min                                2.740647e+07
# 25%                                2.782857e+07
# 50%                                2.819785e+07
# 75%                                2.987852e+07
# max                                3.002468e+07

# %%
new_df.set_index('Period',inplace=True)

# %%
new_df=new_df.drop(['period'],axis=1)

# %%
new_df
# Out:
#             The_average_annual_payroll_of_the_region
# Period
# 2015-01-01                                  30024676
# 2015-01-02                                  30024676
# 2015-01-03                                  30024676
# 2015-01-04                                  30024676
# 2015-01-05                                  30024676
# ...                                              ...
# 2019-01-12                                  29878525
# 2020-01-01                                  29044998
# 2020-01-02                                  29044998
# 2020-01-03                                  29044998
# 2020-01-04                                  29044998
#
# [64 rows x 1 columns]

# %%
new_df.plot(xlim=['2015-01-01','2020-01-04'])
# Out:
# <Axes: xlabel='Period'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(new_df['The_average_annual_payroll_of_the_region'])

# %%
def adfuller_test(The_average_annual_payroll_of_the_region):
    result=adfuller(The_average_annual_payroll_of_the_region)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(new_df['The_average_annual_payroll_of_the_region'])
# Out:
# ADF Test Statistic : -1.7058371131117158
# p-value : 0.42810755783977367
# #Lags Used : 0
# Number of Observations Used : 63
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# Differencing

# %%
new_df['The_average_annual_payroll_of_the_region First Difference'] = new_df['The_average_annual_payroll_of_the_region'] - new_df['The_average_annual_payroll_of_the_region'].shift(1)

# %%
new_df['The_average_annual_payroll_of_the_region'].shift(1)
# Out:
# Period
# 2015-01-01           NaN
# 2015-01-02    30024676.0
# 2015-01-03    30024676.0
# 2015-01-04    30024676.0
# 2015-01-05    30024676.0
#                  ...
# 2019-01-12    29878525.0
# 2020-01-01    29878525.0
# 2020-01-02    29044998.0
# 2020-01-03    29044998.0
# 2020-01-04    29044998.0
# Name: The_average_annual_payroll_of_the_region, Length: 64, dtype: float64

# %%
new_df['Seasonal First Difference']=new_df['The_average_annual_payroll_of_the_region']-new_df['The_average_annual_payroll_of_the_region'].shift(12)

# %%
new_df.head(14)
# Out:
#             The_average_annual_payroll_of_the_region  \
# Period
# 2015-01-01                                  30024676
# 2015-01-02                                  30024676
# 2015-01-03                                  30024676
# 2015-01-04                                  30024676
# 2015-01-05                                  30024676
# 2015-01-06                                  30024676
# 2015-01-07                                  30024676
# 2015-01-08                                  30024676
# 2015-01-09                                  30024676
# 2015-01-10                                  30024676
# 2015-01-11                                  30024676
# 2015-01-12                                  30024676
# 2016-01-01                                  27828571
# 2016-01-02                                  27828571
#
#             The_average_annual_payroll_of_the_region First Difference  \
# Period
# 2015-01-01                                                NaN
# ...

# %%
adfuller_test(new_df['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -1.616714750134893
# p-value : 0.4744520433414913
# #Lags Used : 0
# Number of Observations Used : 51
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
new_df['Seasonal First Difference'].plot()
# Out:
# <Axes: xlabel='Period'>

# %% [markdown]
# Auto Regressive Model
# ![image.png](attachment:image.png)

# %%
from pandas.plotting import autocorrelation_plot

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(new_df['The_average_annual_payroll_of_the_region'])
plt.show()

# %%
pip install statsmodels

# %%
import statsmodels.api as sm

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(new_df['Seasonal First Difference'].iloc[13:],lags=48,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(new_df['Seasonal First Difference'].iloc[13:],lags=12,ax=ax2)

# %%
pip install --upgrade statsmodels

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
time_series_data = new_df['The_average_annual_payroll_of_the_region']

# %%
order = (0, 1, 1)

# %%
model = sm.tsa.arima.ARIMA(time_series_data, order=order)
model_fit = model.fit()

# %%
print(model_fit.summary())
# Out:
#                                           SARIMAX Results
# ...
# Dep. Variable:     The_average_annual_payroll_of_the_region   No. Observations:                   64
# Model:                                       ARIMA(0, 1, 1)   Log Likelihood                -899.050
# Date:                                      Sat, 25 Nov 2023   AIC                           1802.100
# Time:                                              09:41:41   BIC                           1806.386
# Sample:                                                   0   HQIC                          1803.786
#                                                        - 64
# Covariance Type:                                        opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1      -1.869e-09    9.2e+04  -2.03e-14      1.000    -1.8e+05     1.8e+05
# ...

# %%
new_df
# Out:
#             The_average_annual_payroll_of_the_region  \
# Period
# 2015-01-01                                       NaN
# 2015-01-02                                       NaN
# 2015-01-03                                       NaN
# 2015-01-04                                       NaN
# 2015-01-05                                       NaN
# ...                                              ...
# 2019-01-12                                       NaN
# 2020-01-01                                       NaN
# 2020-01-02                                       NaN
# 2020-01-03                                       NaN
# 2020-01-04                                       NaN
#
#             The_average_annual_payroll_of_the_region First Difference  \
# Period
# 2015-01-01                                                NaN
# 2015-01-02                                                0.0
# 2015-01-03                                                0.0
# ...

# %%
new_df['The_average_annual_payroll_of_the_region First Difference']=model_fit.predict(start=60,end=93)
new_df[['The_average_annual_payroll_of_the_region','The_average_annual_payroll_of_the_region First Difference']].plot(figsize=(8,8))
# Out:
# <Axes: xlabel='Period'>
